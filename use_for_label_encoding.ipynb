# %%
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Use this notebook to convert input csv into encoded output csv
# All columns will be encoded to integer categories

# %%
# Input  your filepath
filepath = "Resources/updated_tickets_2024_09_selected.csv"

# Read the csv from filepath
data = Path(filepath)
df = pd.read_csv(data)
df
# Out:
#        WEEKEND                  ISSUING_AGENCY_NAME  \
# 0            1  US. BUREAU OF ENGRAVING AND PRINTNG
# 1            1  US. BUREAU OF ENGRAVING AND PRINTNG
# 2            1  US. BUREAU OF ENGRAVING AND PRINTNG
# 3            1  US. BUREAU OF ENGRAVING AND PRINTNG
# 4            1  US. BUREAU OF ENGRAVING AND PRINTNG
# ...        ...                                  ...
# 97473        0           DEPARTMENT OF PUBLIC WORKS
# 97474        0           DEPARTMENT OF PUBLIC WORKS
# 97475        0           DEPARTMENT OF PUBLIC WORKS
# 97476        0           DEPARTMENT OF PUBLIC WORKS
# 97477        0           DEPARTMENT OF PUBLIC WORKS
#
#       GENERAL_VIOLATION_CATEGORY  \
# 0                 Sign Violation
# 1         Tag/Registration Issue
# 2         Tag/Registration Issue
# 3         Tag/Registration Issue
# 4         Tag/Registration Issue
# ...                          ...
# 97473             Sign Violation
# 97474          Parking Violation
# ...

# %%
# Encode all existing columns to new categorical columns
label_encoders = {}
for column in df:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
    label_encoders[column] = le
label_encoders
# Out:
# {'WEEKEND': LabelEncoder(),
#  'ISSUING_AGENCY_NAME': LabelEncoder(),
#  'GENERAL_VIOLATION_CATEGORY': LabelEncoder(),
#  'NEIGHBORHOOD': LabelEncoder(),
#  'PLATE_STATE': LabelEncoder(),
#  'PERIOD_OF_DAY': LabelEncoder()}

# %%
# Export df to csv
df.to_csv("Resources/encoded_tickets_2024_09_selected.csv", index=False)
